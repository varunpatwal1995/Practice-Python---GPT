# %% [markdown]
# <a href="https://colab.research.google.com/github/varunpatwal1995/Practice-Python---GPT/blob/main/PRACTICE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Python setup test successful!")
# Out:
# Python setup test successful!

# %%
name = "Varun"
goal = "become the most confident Python guy"
print(f"Hello {name}! Your goal is to {goal}")
# Out:
# Hello Varun! Your goal is to become the most confident Python guy

# %%
length = 8
width = 6
# area = length × width
# perimeter = 2 × (length + width)

print("Area = ", length*width)
print("Perimeter =" , 2 * (length + width))
# Out:
# Area =  48
# Perimeter = 28

# %%
price = "2500"
Total = int(price) + 500
print(Total)
# Out:
# 3000

# %%
x = 7
y = 2
# Sum = 9, Difference = 5, Product = 14, Division = 3.5
sum = x + y
difference = x - y
product = x*y
division = x/y

print(f"The sum {sum}, while the difference is {difference}, and the product is {product} and is you divide answer is {division}")
# Out:
# The sum 9, while the difference is 5, and the product is 14 and is you divide answer is 3.5

# %%
# What does type(3.0) return?

# Is bool("") True or False?

# Which operator checks equality — = or ==?

print(type(3.0))
print(bool(""))
# ==
# Out:
# <class 'float'>
# False
